# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from IPython.display import display
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/census-data/Census Variable.csv

# %% [markdown]
# # **Census Data Analysis**
#
# In this notebook, we will perform various data preprocessing techniques on a census dataframe.
#
# # **Reading in the Census Dataframe**

# %%
census = pd.read_csv('/kaggle/input/census-data/Census Variable.csv', index_col=0)

# %% [markdown]
# We read in the census dataframe from a CSV file named 'census_data.csv' using pd.read_csv(). The index_col=0 parameter specifies that the first column should be used as the index.
#
# # **Assessing Variable Types**

# %%
display(census.style.background_gradient(cmap='YlGnBu'))

# Get the data types of the columns
dtypes_df = census.dtypes.reset_index()
dtypes_df.columns = ['Column', 'Data Type']

# Apply styling to the DataFrame
styled_dtypes_df = dtypes_df.style.set_properties(**{'text-align': 'left', 'font-size': '12px'})\
                                   .set_table_styles([{'selector': 'th', 'props': [('background-color', '#edf8b4')]}])\
                                   .set_table_attributes('style="border-collapse: collapse; border: 1px solid black;"')\
                                    .set_caption('Data Types of Census Columns')      
# Display the styled DataFrame
display(styled_dtypes_df)
# Out:
# <style type="text/css">
# #T_0d915_row0_col4, #T_0d915_row1_col4, #T_0d915_row5_col4, #T_0d915_row11_col4, #T_0d915_row18_col4, #T_0d915_row19_col4, #T_0d915_row24_col4, #T_0d915_row28_col4, #T_0d915_row31_col4, #T_0d915_row35_col4, #T_0d915_row41_col4, #T_0d915_row44_col5, #T_0d915_row49_col4, #T_0d915_row62_col4, #T_0d915_row63_col4, #T_0d915_row66_col4, #T_0d915_row70_col4, #T_0d915_row71_col4, #T_0d915_row72_col4, #T_0d915_row75_col4, #T_0d915_row78_col4, #T_0d915_row81_col4, #T_0d915_row88_col4, #T_0d915_row90_col4, #T_0d915_row93_col4, #T_0d915_row97_col4 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_0d915_row0_col5 {
#   background-color: #8ed3ba;
#   color: #000000;
# }
# #T_0d915_row1_col5, #T_0d915_row22_col5, #T_0d915_row70_col5 {
#   background-color: #c8e9b4;
#   color: #000000;
# }
# #T_0d915_row2_col4, #T_0d915_row3_col4, #T_0d915_row4_col4, #T_0d915_row7_col4, #T_0d915_row20_col4, #T_0d915_row42_col4, #T_0d915_row47_col4, #T_0d915_row50_col4, #T_0d915_row53_col4, #T_0d915_row59_col4, #T_0d915_row60_col4, #T_0d915_row76_col4, #T_0d915_row79_col4, #T_0d915_row80_col4, #T_0d915_row84_col4, #T_0d915_row85_col4 {
#   background-color: #40b5c4;
#   color: #f1f1f1;
# }
# #T_0d915_row2_col5 {
#   background-color: #234c9f;
#   color: #f1f1f1;
# }
# #T_0d915_row3_col5 {
#   background-color: #d0edb3;
#   color: #000000;
# }
# #T_0d915_row4_col5 {
#   background-color: #1f82b9;
#   color: #f1f1f1;
# }
# #T_0d915_row5_col5, #T_0d915_row21_col5 {
#   background-color: #2258a5;
#   color: #f1f1f1;
# }
# #T_0d915_row6_col4, #T_0d915_row8_col4, #T_0d915_row22_col4, #T_0d915_row26_col4, #T_0d915_row27_col4, #T_0d915_row33_col4, #T_0d915_row36_col4, #T_0d915_row37_col4, #T_0d915_row38_col4, #T_0d915_row39_col4, #T_0d915_row43_col4, #T_0d915_row48_col4, #T_0d915_row51_col4, #T_0d915_row59_col5, #T_0d915_row61_col4, #T_0d915_row65_col4, #T_0d915_row67_col4, #T_0d915_row68_col4, #T_0d915_row77_col4, #T_0d915_row81_col5, #T_0d915_row82_col4, #T_0d915_row89_col4, #T_0d915_row92_col4, #T_0d915_row96_col4 {
#   background-color: #c6e9b4;
#   color: #000000;
# }
# #T_0d915_row6_col5, #T_0d915_row52_col5 {
#   background-color: #f3fabd;
#   color: #000000;
# }
# #T_0d915_row7_col5 {
#   background-color: #1e88bc;
#   color: #f1f1f1;
# }
# #T_0d915_row8_col5, #T_0d915_row87_col5 {
#   background-color: #37acc3;
#   color: #f1f1f1;
# }
# #T_0d915_row9_col4, #T_0d915_row13_col4, #T_0d915_row14_col4, #T_0d915_row17_col4, #T_0d915_row21_col4, #T_0d915_row30_col4, #T_0d915_row44_col4, #T_0d915_row46_col4, #T_0d915_row54_col4, #T_0d915_row56_col4, #T_0d915_row73_col4, #T_0d915_row79_col5, #T_0d915_row86_col4, #T_0d915_row87_col4, #T_0d915_row91_col4, #T_0d915_row94_col4, #T_0d915_row98_col4 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_0d915_row9_col5, #T_0d915_row95_col5 {
#   background-color: #225ea8;
#   color: #f1f1f1;
# }
# #T_0d915_row10_col4, #T_0d915_row12_col4, #T_0d915_row15_col4, #T_0d915_row16_col4, #T_0d915_row23_col4, #T_0d915_row25_col4, #T_0d915_row29_col4, #T_0d915_row32_col4, #T_0d915_row34_col4, #T_0d915_row40_col4, #T_0d915_row45_col4, #T_0d915_row52_col4, #T_0d915_row55_col4, #T_0d915_row57_col4, #T_0d915_row58_col4, #T_0d915_row64_col4, #T_0d915_row69_col4, #T_0d915_row74_col4, #T_0d915_row83_col4, #T_0d915_row95_col4, #T_0d915_row99_col4 {
#   background-color: #225da8;
#   color: #f1f1f1;
# }
# #T_0d915_row10_col5, #T_0d915_row61_col5, #T_0d915_row74_col5 {
#   background-color: #2296c1;
#   color: #f1f1f1;
# }
# #T_0d915_row11_col5 {
#   background-color: #fcfed3;
#   color: #000000;
# }
# #T_0d915_row12_col5 {
#   background-color: #0d2161;
#   color: #f1f1f1;
# }
# #T_0d915_row13_col5 {
#   background-color: #203089;
#   color: #f1f1f1;
# }
# #T_0d915_row14_col5 {
#   background-color: #3cb1c3;
#   color: #f1f1f1;
# }
# #T_0d915_row15_col5 {
#   background-color: #6fc7bd;
#   color: #000000;
# }
# #T_0d915_row16_col5 {
#   background-color: #c9eab4;
#   color: #000000;
# }
# #T_0d915_row17_col5 {
#   background-color: #0e2265;
#   color: #f1f1f1;
# }
# #T_0d915_row18_col5 {
#   background-color: #dbf1b2;
#   color: #000000;
# }
# #T_0d915_row19_col5, #T_0d915_row25_col5, #T_0d915_row56_col5 {
#   background-color: #b9e4b5;
#   color: #000000;
# }
# #T_0d915_row20_col5 {
#   background-color: #f0f9b8;
#   color: #000000;
# }
# #T_0d915_row23_col5, #T_0d915_row39_col5, #T_0d915_row54_col5 {
#   background-color: #f5fbc4;
#   color: #000000;
# }
# #T_0d915_row24_col5 {
#   background-color: #4ebbc2;
#   color: #000000;
# }
# #T_0d915_row26_col5 {
#   background-color: #a0dab8;
#   color: #000000;
# }
# #T_0d915_row27_col5 {
#   background-color: #2165ab;
#   color: #f1f1f1;
# }
# #T_0d915_row28_col5, #T_0d915_row47_col5 {
#   background-color: #f4fbc1;
#   color: #000000;
# }
# #T_0d915_row29_col5 {
#   background-color: #59bfc0;
#   color: #000000;
# }
# #T_0d915_row30_col5 {
#   background-color: #142670;
#   color: #f1f1f1;
# }
# #T_0d915_row31_col5 {
#   background-color: #f4fbc0;
#   color: #000000;
# }
# #T_0d915_row32_col5, #T_0d915_row88_col5 {
#   background-color: #2073b2;
#   color: #f1f1f1;
# }
# #T_0d915_row33_col5 {
#   background-color: #42b6c4;
#   color: #f1f1f1;
# }
# #T_0d915_row34_col5 {
#   background-color: #091e5a;
#   color: #f1f1f1;
# }
# #T_0d915_row35_col5 {
#   background-color: #63c3bf;
#   color: #000000;
# }
# #T_0d915_row36_col5, #T_0d915_row68_col5 {
#   background-color: #f7fcc7;
#   color: #000000;
# }
# #T_0d915_row37_col5 {
#   background-color: #d6efb3;
#   color: #000000;
# }
# #T_0d915_row38_col5 {
#   background-color: #76cabc;
#   color: #000000;
# }
# #T_0d915_row40_col5, #T_0d915_row92_col5 {
#   background-color: #253997;
#   color: #f1f1f1;
# }
# #T_0d915_row41_col5 {
#   background-color: #75c9bd;
#   color: #000000;
# }
# #T_0d915_row42_col5 {
#   background-color: #4cbac2;
#   color: #f1f1f1;
# }
# #T_0d915_row43_col5 {
#   background-color: #67c4be;
#   color: #000000;
# }
# #T_0d915_row45_col5 {
#   background-color: #e8f6b1;
#   color: #000000;
# }
# #T_0d915_row46_col5 {
#   background-color: #216bae;
#   color: #f1f1f1;
# }
# #T_0d915_row48_col5 {
#   background-color: #24439b;
#   color: #f1f1f1;
# }
# #T_0d915_row49_col5 {
#   background-color: #0f2367;
#   color: #f1f1f1;
# }
# #T_0d915_row50_col5, #T_0d915_row53_col5 {
#   background-color: #152772;
#   color: #f1f1f1;
# }
# #T_0d915_row51_col5 {
#   background-color: #1e2e85;
#   color: #f1f1f1;
# }
# #T_0d915_row55_col5 {
#   background-color: #b4e2b6;
#   color: #000000;
# }
# #T_0d915_row57_col5 {
#   background-color: #31a5c2;
#   color: #f1f1f1;
# }
# #T_0d915_row58_col5 {
#   background-color: #2397c1;
#   color: #f1f1f1;
# }
# #T_0d915_row60_col5, #T_0d915_row80_col5 {
#   background-color: #d5efb3;
#   color: #000000;
# }
# #T_0d915_row62_col5 {
#   background-color: #bbe4b5;
#   color: #000000;
# }
# #T_0d915_row63_col5 {
#   background-color: #eef8b3;
#   color: #000000;
# }
# #T_0d915_row64_col5 {
#   background-color: #172976;
#   color: #f1f1f1;
# }
# #T_0d915_row65_col5 {
#   background-color: #99d7b8;
#   color: #000000;
# }
# #T_0d915_row66_col5, #T_0d915_row72_col5 {
#   background-color: #97d6b9;
#   color: #000000;
# }
# #T_0d915_row67_col5 {
#   background-color: #4ab9c3;
#   color: #f1f1f1;
# }
# #T_0d915_row69_col5, #T_0d915_row85_col5 {
#   background-color: #182a7a;
#   color: #f1f1f1;
# }
# #T_0d915_row71_col5 {
#   background-color: #d7efb3;
#   color: #000000;
# }
# #T_0d915_row73_col5 {
#   background-color: #216aad;
#   color: #f1f1f1;
# }
# #T_0d915_row75_col5 {
#   background-color: #95d5b9;
#   color: #000000;
# }
# #T_0d915_row76_col5 {
#   background-color: #d4eeb3;
#   color: #000000;
# }
# #T_0d915_row77_col5 {
#   background-color: #299dc1;
#   color: #f1f1f1;
# }
# #T_0d915_row78_col5 {
#   background-color: #233390;
#   color: #f1f1f1;
# }
# #T_0d915_row82_col5 {
#   background-color: #172978;
#   color: #f1f1f1;
# }
# #T_0d915_row83_col5 {
#   background-color: #3fb4c4;
#   color: #f1f1f1;
# }
# #T_0d915_row84_col5 {
#   background-color: #50bbc2;
#   color: #000000;
# }
# #T_0d915_row86_col5 {
#   background-color: #f2fabc;
#   color: #000000;
# }
# #T_0d915_row89_col5 {
#   background-color: #35aac3;
#   color: #f1f1f1;
# }
# #T_0d915_row90_col5 {
#   background-color: #46b8c3;
#   color: #f1f1f1;
# }
# #T_0d915_row91_col5 {
#   background-color: #a5dcb7;
#   color: #000000;
# }
# #T_0d915_row93_col5, #T_0d915_row96_col5 {
#   background-color: #e3f4b2;
#   color: #000000;
# }
# #T_0d915_row94_col5 {
#   background-color: #21308b;
#   color: #f1f1f1;
# }
# #T_0d915_
# <style type="text/css">
# #T_b73cf th {
#   background-color: #edf8b4;
# }
# #T_b73cf_row0_col0, #T_b73cf_row0_col1, #T_b73cf_row1_col0, #T_b73cf_row1_col1, #T_b73cf_row2_col0, #T_b73cf_row2_col1, #T_b73cf_row3_col0, #T_b73cf_row3_col1, #T_b73cf_row4_col0, #T_b73cf_row4_col1, #T_b73cf_row5_col0, #T_b73cf_row5_col1, #T_b73cf_row6_col0, #T_b73cf_row6_col1, #T_b73cf_row7_col0, #T_b73cf_row7_col1 {
#   text-align: left;
#   font-size: 12px;
# }
# </style>
# <table id="T_b73cf" style="border-collapse: collapse; border: 1px solid black;">
#   <caption>Data Types of Census Columns</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b73cf_level0_col0" class="col_heading level0 col0" >Column</th>
#       <th id="T_b73cf_level0_col1" class="col_heading level0 col1" >Data Type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b73cf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b73cf_row0_col0" class="data row0 col0" >first_name</td>
#       <td id="T_b73cf_row0_col1" class="data row0 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_b73cf_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b73cf_row1_col0" class="data row1 col0" >last_name</td>
#       <td id="T_b73cf_row1_col1" class="data row1 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_b73cf_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b73cf_row2_col0" class="data row2 col0" >birth_year</td>
#       <td id="T_b73cf_row2_col1" class="data row2 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_b73cf_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b73cf_row3_col0" class="data row3 col0" >voted</td>
#       <td id="T_b73cf_row3_col1" class="data row3 col1" >bool</td>
#     </tr>
#     <tr>
#       <th id="T_b73cf_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b73cf_row4_col0" class="data row4 col0" >num_children</td>
#       <td id="T_b73cf_row4_col1" class="data row4 col1" >int64</td>
#     </tr>
#     <tr>
#       <th id="T_b73cf_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b73cf_row5_col0" class="data row5 col0" >income_year</td>
#       <td id="T_b73cf_row5_col1" class="data row5 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_b73cf_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b73cf_row6_col0" class="data row6 col0" >higher_tax</td>
#       <td id="T_b73cf_row6_col1" class="data row6 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_b73cf_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b73cf_row7_col0" class="data row7 col0" >marital_status</td>
#       <td id="T_b73cf_row7_col1" class="data row7 col1" >object</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# We print out the beginning of the census dataframe using print(census) to inspect its contents.  Next we inspect the data types of each column in the census dataframe, helping us assess the variable types.
#
# # **Inspecting Datatypes**

# %%
# Get the unique values of the 'birth_year' column
unique_birth_years = census['birth_year'].unique()

# Create a new DataFrame with the unique values
unique_df = pd.DataFrame({'Birth Year': unique_birth_years})

# Apply styling to the DataFrame
styled_unique_df = unique_df.style.set_properties(**{'text-align': 'center', 'font-weight': 'bold'})\
                                  .set_caption('Unique Birth Years')\
                                  .set_table_styles([{'selector': 'th', 'props': [('background-color', '#ff9999')]}])\
                                  .set_table_attributes('style="border-collapse: collapse; border: 1px solid black;"')
display(styled_unique_df)
# Out:
# <style type="text/css">
# #T_a26ac th {
#   background-color: #ff9999;
# }
# #T_a26ac_row0_col0, #T_a26ac_row1_col0, #T_a26ac_row2_col0, #T_a26ac_row3_col0, #T_a26ac_row4_col0, #T_a26ac_row5_col0, #T_a26ac_row6_col0, #T_a26ac_row7_col0, #T_a26ac_row8_col0, #T_a26ac_row9_col0, #T_a26ac_row10_col0, #T_a26ac_row11_col0, #T_a26ac_row12_col0, #T_a26ac_row13_col0, #T_a26ac_row14_col0, #T_a26ac_row15_col0, #T_a26ac_row16_col0, #T_a26ac_row17_col0, #T_a26ac_row18_col0, #T_a26ac_row19_col0, #T_a26ac_row20_col0, #T_a26ac_row21_col0, #T_a26ac_row22_col0, #T_a26ac_row23_col0, #T_a26ac_row24_col0, #T_a26ac_row25_col0, #T_a26ac_row26_col0, #T_a26ac_row27_col0, #T_a26ac_row28_col0, #T_a26ac_row29_col0, #T_a26ac_row30_col0, #T_a26ac_row31_col0, #T_a26ac_row32_col0, #T_a26ac_row33_col0, #T_a26ac_row34_col0, #T_a26ac_row35_col0, #T_a26ac_row36_col0, #T_a26ac_row37_col0, #T_a26ac_row38_col0, #T_a26ac_row39_col0, #T_a26ac_row40_col0, #T_a26ac_row41_col0, #T_a26ac_row42_col0, #T_a26ac_row43_col0, #T_a26ac_row44_col0, #T_a26ac_row45_col0, #T_a26ac_row46_col0, #T_a26ac_row47_col0, #T_a26ac_row48_col0, #T_a26ac_row49_col0, #T_a26ac_row50_col0, #T_a26ac_row51_col0, #T_a26ac_row52_col0 {
#   text-align: center;
#   font-weight: bold;
# }
# </style>
# <table id="T_a26ac" style="border-collapse: collapse; border: 1px solid black;">
#   <caption>Unique Birth Years</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a26ac_level0_col0" class="col_heading level0 col0" >Birth Year</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a26ac_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a26ac_row0_col0" class="data row0 col0" >2005</td>
#     </tr>
#     <tr>
#       <th id="T_a26ac_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a26ac_row1_col0" class="data row1 col0" >1987</td>
#     </tr>
#     <tr>
#       <th id="T_a26ac_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a26ac_row2_col0" class="data row2 col0" >1992</td>
#     </tr>
#     <tr>
#       <th id="T_a26ac_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a26ac_row3_col0" class="data row3 col0" >1965</td>
#     </tr>
#     <tr>
#       <th id="T_a26ac_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a26ac_row4_col0" class="data row4 col0" >1945</td>
#     </tr>
#     <tr>
#       <th id="T_a26ac_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a26ac_row5_col0" class="data row5 col0" >1951</td>
#     </tr>
#     <tr>
#       <th id="T_a26ac_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a26ac_row6_col0" class="data row6 col0" >1963</td>
#     </tr>
#     <tr>
#       <th id="T_a26ac_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a26ac_row7_col0" class="data row7 col0" >1949</td>
#     </tr>
#     <tr>
#       <th id="T_a26ac_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a26ac_row8_col0" class="data row8 col0" >1950</td>
#     </tr>
#     <tr>
#       <th id="T_a26ac_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a26ac_row9_col0" class="data row9 col0" >1971</td>
#     </tr>
#     <tr>
#       <th id="T_a26ac_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_a26ac_row10_col0" class="data row10 col0" >2007</td>
#     </tr>
#     <tr>
#       <th id="T_a26ac_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_a26ac_row11_col0" class="data row11 col0" >1944</td>
#     </tr>
#     <tr>
#       <th id="T_a26ac_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_a26ac_row12_col0" class="data row12 col0" >1995</td>
#     </tr>
#     <tr>
#       <th id="T_a26ac_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_a26ac_row13_col0" class="data row13 col0" >1973</td>
#     </tr>
#     <tr>
#       <th id="T_a26ac_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_a26ac_row14_col0" class="data row14 col0" >1946</td>
#     </tr>
#     <tr>
#       <th id="T_a26ac_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_a26ac_row15_col0" class="data row15 col0" >1954</td>
#     </tr>
#     <tr>
#       <th id="T_a26ac_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_a26ac_row16_col0" class="data row16 col0" >1994</td>
#     </tr>
#     <tr>
#       <th id="T_a26ac_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_a26ac_row17_col0" class="data row17 col0" >1989</td>
#     </tr>
#     <tr>
#       <th id="T_a26ac_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_a26ac_row18_col0" class="data row18 col0" >1947</td>
#     </tr>
#     <tr>
#       <th id="T_a26ac_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_a26ac_row19_col0" class="data row19 col0" >1993</td>
#     </tr>
#     <tr>
#       <th id="T_a26ac_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_a26ac_row20_col0" class="data row20 col0" >1976</td>
#     </tr>
#     <tr>
#       <th id="T_a26ac_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_a26ac_row21_col0" class="data row21 col0" >1984</td>
#     </tr>
#     <tr>
#       <th id="T_a26ac_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_a26ac_row22_col0" class="data row22 col0" >missing</td>
#     </tr>
#     <tr>
#       <th id="T_a26ac_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_a26ac_row23_col0" class="data row23 col0" >1966</td>
#     </tr>
#     <tr>
#       <th id="T_a26ac_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_a26ac_row24_col0" class="data row24 col0" >1941</td>
#     </tr>
#     <tr>
#       <th id="T_a26ac_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_a26ac_row25_col0" class="data row25 col0" >2000</td>
#     </tr>
#     <tr>
#       <th id="T_a26ac_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_a26ac_row26_col0" class="data row26 col0" >1953</td>
#     </tr>
#     <tr>
#       <th id="T_a26ac_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_a26ac_row27_col0" class="data row27 col0" >1956</td>
#     </tr>
#     <tr>
#       <th id="T_a26ac_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_a26ac_row28_col0" class="data row28 col0" >1960</td>
#     </tr>
#     <tr>
#       <th id="T_a26ac_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_a26ac_row29_col0" class="data row29 col0" >2001</td>
#     </tr>
#     <tr>
#       <th id="T_a26ac_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_a26ac_row30_col0" class="data row30 col0" >1980</td>
#     </tr>
#     <tr>
#       <th id="T_a26ac_level0_row31" class="row_heading level0 row31" >31</th>
#       <td id="T_a26ac_row31_col0" class="data row31 col0" >1955</td>
#     </tr>
#     <tr>
#       <th id="T_a26ac_level0_row32" class="row_heading level0 row32" >32</th>
#       <td id="T_a26ac_row32_col0" class="data row32 col0" >1985</td>
#     </tr>
#     <tr>
#       <th id="T_a26ac_level0_row33" class="row_heading level0 row33" >33</th>
#       <td id="T_a26ac_row33_col0" class="data row33 col0" >1996</td>
#     </tr>
#     <tr>
#       <th id="T_a26ac_level0_row34" class="row_heading level0 row34" >34</th>
#       <td id="T_a26ac_row34_col0" class="data row34 col0" >1968</td>
#     </tr>
#     <tr>
#       <th id="T_a26ac_level0_row35" class="row_heading level0 row35" >35</th>
#       <td id="T_a26ac_row35_col0" class="data row35 col0" >1979</td>
#     </tr>
#     <tr>
#       <th id="T_a26ac_level0_row36" class="row_heading level0 row36" >36</th>
#       <td id="T_a26ac_row36_col0" class="data row36 col0" >2006</td>
#     </tr>
#     <tr>
#       <th id="T_a26ac_level0_row37" class="row_heading level0 row37" >37</th>
#       <td id="T_a26ac_row37_col0" class="data row37 col0" >1962</td>
#     </tr>
#     <tr>
#       <th id="T_a26ac_level0_row38" class="row_heading level0 row38" >38</th>
#       <td id="T_a26ac_row38_col0" class="data row38 col0" >1981</td>
#     </tr>
#     <tr>
#       <th id="T_a26ac_level0_row39" cl

# %% [markdown]
# This printed out the unique values in the 'birth_year' column, allowing us to identify any missing or invalid values.
#
# # **Altering Data**

# %%
census['birth_year'] = census['birth_year'].replace(['missing'], 1967)
census['birth_year'] = census['birth_year'].astype('int64')

# Get the unique values of the 'birth_year' column
unique_birth_years = census['birth_year'].unique()

# Create a DataFrame with the unique values
unique_df = pd.DataFrame({'Birth Year': unique_birth_years})

# Apply styling to the DataFrame
styled_unique_df = unique_df.style.set_properties(**{'text-align': 'center', 'font-size': '12px'})\
                                  .set_caption('Unique Birth Years')\
                                  .set_table_styles([{'selector': 'th', 'props': [('background-color', '#ff9999')]}])\
                                  .set_table_attributes('style="border-collapse: collapse; border: 1px solid black;"')\
                                  
# Display the styled DataFrame
display(styled_unique_df)

# Get the data types of the columns
dtypes_df = census.dtypes.reset_index()
dtypes_df.columns = ['Column', 'Data Type']

# Apply styling to the DataFrame
styled_dtypes_df = dtypes_df.style.set_properties(**{'text-align': 'left', 'font-size': '12px'})\
                                   .set_table_styles([{'selector': 'th', 'props': [('background-color', '#edf8b4')]}])\
                                   .set_table_attributes('style="border-collapse: collapse; border: 1px solid black;"')\
                                    .set_caption('Data Types of Census Columns')      
# Display the styled DataFrame
display(styled_dtypes_df)

print(census['birth_year'].mean())
# Out:
# <style type="text/css">
# #T_76764 th {
#   background-color: #ff9999;
# }
# #T_76764_row0_col0, #T_76764_row1_col0, #T_76764_row2_col0, #T_76764_row3_col0, #T_76764_row4_col0, #T_76764_row5_col0, #T_76764_row6_col0, #T_76764_row7_col0, #T_76764_row8_col0, #T_76764_row9_col0, #T_76764_row10_col0, #T_76764_row11_col0, #T_76764_row12_col0, #T_76764_row13_col0, #T_76764_row14_col0, #T_76764_row15_col0, #T_76764_row16_col0, #T_76764_row17_col0, #T_76764_row18_col0, #T_76764_row19_col0, #T_76764_row20_col0, #T_76764_row21_col0, #T_76764_row22_col0, #T_76764_row23_col0, #T_76764_row24_col0, #T_76764_row25_col0, #T_76764_row26_col0, #T_76764_row27_col0, #T_76764_row28_col0, #T_76764_row29_col0, #T_76764_row30_col0, #T_76764_row31_col0, #T_76764_row32_col0, #T_76764_row33_col0, #T_76764_row34_col0, #T_76764_row35_col0, #T_76764_row36_col0, #T_76764_row37_col0, #T_76764_row38_col0, #T_76764_row39_col0, #T_76764_row40_col0, #T_76764_row41_col0, #T_76764_row42_col0, #T_76764_row43_col0, #T_76764_row44_col0, #T_76764_row45_col0, #T_76764_row46_col0, #T_76764_row47_col0, #T_76764_row48_col0, #T_76764_row49_col0, #T_76764_row50_col0, #T_76764_row51_col0, #T_76764_row52_col0 {
#   text-align: center;
#   font-size: 12px;
# }
# </style>
# <table id="T_76764" style="border-collapse: collapse; border: 1px solid black;">
#   <caption>Unique Birth Years</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_76764_level0_col0" class="col_heading level0 col0" >Birth Year</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_76764_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_76764_row0_col0" class="data row0 col0" >2005</td>
#     </tr>
#     <tr>
#       <th id="T_76764_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_76764_row1_col0" class="data row1 col0" >1987</td>
#     </tr>
#     <tr>
#       <th id="T_76764_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_76764_row2_col0" class="data row2 col0" >1992</td>
#     </tr>
#     <tr>
#       <th id="T_76764_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_76764_row3_col0" class="data row3 col0" >1965</td>
#     </tr>
#     <tr>
#       <th id="T_76764_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_76764_row4_col0" class="data row4 col0" >1945</td>
#     </tr>
#     <tr>
#       <th id="T_76764_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_76764_row5_col0" class="data row5 col0" >1951</td>
#     </tr>
#     <tr>
#       <th id="T_76764_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_76764_row6_col0" class="data row6 col0" >1963</td>
#     </tr>
#     <tr>
#       <th id="T_76764_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_76764_row7_col0" class="data row7 col0" >1949</td>
#     </tr>
#     <tr>
#       <th id="T_76764_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_76764_row8_col0" class="data row8 col0" >1950</td>
#     </tr>
#     <tr>
#       <th id="T_76764_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_76764_row9_col0" class="data row9 col0" >1971</td>
#     </tr>
#     <tr>
#       <th id="T_76764_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_76764_row10_col0" class="data row10 col0" >2007</td>
#     </tr>
#     <tr>
#       <th id="T_76764_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_76764_row11_col0" class="data row11 col0" >1944</td>
#     </tr>
#     <tr>
#       <th id="T_76764_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_76764_row12_col0" class="data row12 col0" >1995</td>
#     </tr>
#     <tr>
#       <th id="T_76764_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_76764_row13_col0" class="data row13 col0" >1973</td>
#     </tr>
#     <tr>
#       <th id="T_76764_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_76764_row14_col0" class="data row14 col0" >1946</td>
#     </tr>
#     <tr>
#       <th id="T_76764_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_76764_row15_col0" class="data row15 col0" >1954</td>
#     </tr>
#     <tr>
#       <th id="T_76764_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_76764_row16_col0" class="data row16 col0" >1994</td>
#     </tr>
#     <tr>
#       <th id="T_76764_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_76764_row17_col0" class="data row17 col0" >1989</td>
#     </tr>
#     <tr>
#       <th id="T_76764_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_76764_row18_col0" class="data row18 col0" >1947</td>
#     </tr>
#     <tr>
#       <th id="T_76764_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_76764_row19_col0" class="data row19 col0" >1993</td>
#     </tr>
#     <tr>
#       <th id="T_76764_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_76764_row20_col0" class="data row20 col0" >1976</td>
#     </tr>
#     <tr>
#       <th id="T_76764_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_76764_row21_col0" class="data row21 col0" >1984</td>
#     </tr>
#     <tr>
#       <th id="T_76764_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_76764_row22_col0" class="data row22 col0" >1967</td>
#     </tr>
#     <tr>
#       <th id="T_76764_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_76764_row23_col0" class="data row23 col0" >1966</td>
#     </tr>
#     <tr>
#       <th id="T_76764_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_76764_row24_col0" class="data row24 col0" >1941</td>
#     </tr>
#     <tr>
#       <th id="T_76764_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_76764_row25_col0" class="data row25 col0" >2000</td>
#     </tr>
#     <tr>
#       <th id="T_76764_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_76764_row26_col0" class="data row26 col0" >1953</td>
#     </tr>
#     <tr>
#       <th id="T_76764_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_76764_row27_col0" class="data row27 col0" >1956</td>
#     </tr>
#     <tr>
#       <th id="T_76764_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_76764_row28_col0" class="data row28 col0" >1960</td>
#     </tr>
#     <tr>
#       <th id="T_76764_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_76764_row29_col0" class="data row29 col0" >2001</td>
#     </tr>
#     <tr>
#       <th id="T_76764_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_76764_row30_col0" class="data row30 col0" >1980</td>
#     </tr>
#     <tr>
#       <th id="T_76764_level0_row31" class="row_heading level0 row31" >31</th>
#       <td id="T_76764_row31_col0" class="data row31 col0" >1955</td>
#     </tr>
#     <tr>
#       <th id="T_76764_level0_row32" class="row_heading level0 row32" >32</th>
#       <td id="T_76764_row32_col0" class="data row32 col0" >1985</td>
#     </tr>
#     <tr>
#       <th id="T_76764_level0_row33" class="row_heading level0 row33" >33</th>
#       <td id="T_76764_row33_col0" class="data row33 col0" >1996</td>
#     </tr>
#     <tr>
#       <th id="T_76764_level0_row34" class="row_heading level0 row34" >34</th>
#       <td id="T_76764_row34_col0" class="data row34 col0" >1968</td>
#     </tr>
#     <tr>
#       <th id="T_76764_level0_row35" class="row_heading level0 row35" >35</th>
#       <td id="T_76764_row35_col0" class="data row35 col0" >1979</td>
#     </tr>
#     <tr>
#       <th id="T_76764_level0_row36" class="row_heading level0 row36" >36</th>
#       <td id="T_76764_row36_col0" class="data row36 col0" >2006</td>
#     </tr>
#     <tr>
#       <th id="T_76764_level0_row37" class="row_heading level0 row37" >37</th>
#       <td id="T_76764_row37_col0" class="data row37 col0" >1962</td>
#     </tr>
#     <tr>
#       <th id="T_76764_level0_row38" class="row_heading level0 row38" >38</th>
#       <td id="T_76764_row38_col0" class="data row38 col0" >1981</td>
#     </tr>
#     <tr>
#       <th id="T_76764_level0_row39" class="
# <style type="text/css">
# #T_d8c56 th {
#   background-color: #edf8b4;
# }
# #T_d8c56_row0_col0, #T_d8c56_row0_col1, #T_d8c56_row1_col0, #T_d8c56_row1_col1, #T_d8c56_row2_col0, #T_d8c56_row2_col1, #T_d8c56_row3_col0, #T_d8c56_row3_col1, #T_d8c56_row4_col0, #T_d8c56_row4_col1, #T_d8c56_row5_col0, #T_d8c56_row5_col1, #T_d8c56_row6_col0, #T_d8c56_row6_col1, #T_d8c56_row7_col0, #T_d8c56_row7_col1 {
#   text-align: left;
#   font-size: 12px;
# }
# </style>
# <table id="T_d8c56" style="border-collapse: collapse; border: 1px solid black;">
#   <caption>Data Types of Census Columns</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d8c56_level0_col0" class="col_heading level0 col0" >Column</th>
#       <th id="T_d8c56_level0_col1" class="col_heading level0 col1" >Data Type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d8c56_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d8c56_row0_col0" class="data row0 col0" >first_name</td>
#       <td id="T_d8c56_row0_col1" class="data row0 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_d8c56_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d8c56_row1_col0" class="data row1 col0" >last_name</td>
#       <td id="T_d8c56_row1_col1" class="data row1 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_d8c56_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d8c56_row2_col0" class="data row2 col0" >birth_year</td>
#       <td id="T_d8c56_row2_col1" class="data row2 col1" >int64</td>
#     </tr>
#     <tr>
#       <th id="T_d8c56_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d8c56_row3_col0" class="data row3 col0" >voted</td>
#       <td id="T_d8c56_row3_col1" class="data row3 col1" >bool</td>
#     </tr>
#     <tr>
#       <th id="T_d8c56_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d8c56_row4_col0" class="data row4 col0" >num_children</td>
#       <td id="T_d8c56_row4_col1" class="data row4 col1" >int64</td>
#     </tr>
#     <tr>
#       <th id="T_d8c56_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d8c56_row5_col0" class="data row5 col0" >income_year</td>
#       <td id="T_d8c56_row5_col1" class="data row5 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_d8c56_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d8c56_row6_col0" class="data row6 col0" >higher_tax</td>
#       <td id="T_d8c56_row6_col1" class="data row6 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_d8c56_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d8c56_row7_col0" class="data row7 col0" >marital_status</td>
#       <td id="T_d8c56_row7_col1" class="data row7 col1" >object</td>
#     </tr>
#   </tbody>
# </table>
# 1973.4

# %% [markdown]
# We replaced the value 'missing' in the 'birth_year' column with the integer value 1967 using census['birth_year'].replace(['missing'], 1967) to handle missing data. Then, we convert the data type of the 'birth_year' column to 'object' using census['birth_year'].astype('object').
#
# We print out the unique values in the 'birth_year' column after the replacement and data type conversion, the data types of each column, and the mean value of the 'birth_year' column.
#
# # **Assigning Categorical Order and Label Encoding**

# %%
# Assign categorical order to the 'higher_tax' column
census['higher_tax'] = pd.Categorical(census['higher_tax'], ['strongly disagree', 'disagree', 'neutral', 'agree', 'strongly agree'], ordered=True)

# Get the unique categories of the 'higher_tax' column
unique_categories = census['higher_tax'].unique()

# Convert the unique categories back to Categorical dtype
unique_categories = pd.Categorical(unique_categories, categories=census['higher_tax'].cat.categories, ordered=True)

# Create a DataFrame with the unique categories
unique_df = pd.DataFrame({'Higher Tax Categories': unique_categories, 'Category Code': unique_categories.codes})


# Sort the DataFrame based on the 'Code' column
unique_df = unique_df.sort_values('Category Code')

# Apply styling to the unique categories DataFrame
styled_unique_df = unique_df.style.set_properties(**{'text-align': 'center', 'font-size': '14px', 'font-family': 'Arial'})\
                                  .set_caption('Unique Higher Tax Categories')\
                                  .set_table_styles([{'selector': 'th', 'props': [('background-color', '#66b3ff'), ('color', 'white')]},
                                                     {'selector': 'td', 'props': [('border', '1px solid #66b3ff'), ('padding', '5px')]}])
display(styled_unique_df)

# Convert the 'higher_tax' column to numeric codes
census['higher_tax'] = census['higher_tax'].cat.codes

# Calculate the median value of the 'higher_tax' column
median_value = census['higher_tax'].median()

# Create a DataFrame with the median value
median_df = pd.DataFrame({'Median Higher Tax': [median_value]})

# Apply styling to the median value DataFrame
styled_median_df = median_df.style.set_properties(**{'text-align': 'center', 'font-size': '16px', 'font-weight': 'bold', 'font-family': 'Arial'})\
                                  .set_caption('Median Higher Tax Value')\
                                  .set_table_styles([{'selector': 'th', 'props': [('background-color', '#ff9933'), ('color', 'white')]},
                                                     {'selector': 'td', 'props': [('border', '1px solid #ff9933'), ('padding', '5px')]}])

display(styled_median_df)
# Out:
# <style type="text/css">
# #T_7e252 th {
#   background-color: #66b3ff;
#   color: white;
# }
# #T_7e252 td {
#   border: 1px solid #66b3ff;
#   padding: 5px;
# }
# #T_7e252_row0_col0, #T_7e252_row0_col1, #T_7e252_row1_col0, #T_7e252_row1_col1, #T_7e252_row2_col0, #T_7e252_row2_col1, #T_7e252_row3_col0, #T_7e252_row3_col1, #T_7e252_row4_col0, #T_7e252_row4_col1 {
#   text-align: center;
#   font-size: 14px;
#   font-family: Arial;
# }
# </style>
# <table id="T_7e252">
#   <caption>Unique Higher Tax Categories</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7e252_level0_col0" class="col_heading level0 col0" >Higher Tax Categories</th>
#       <th id="T_7e252_level0_col1" class="col_heading level0 col1" >Category Code</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7e252_level0_row0" class="row_heading level0 row0" >4</th>
#       <td id="T_7e252_row0_col0" class="data row0 col0" >strongly disagree</td>
#       <td id="T_7e252_row0_col1" class="data row0 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_7e252_level0_row1" class="row_heading level0 row1" >0</th>
#       <td id="T_7e252_row1_col0" class="data row1 col0" >disagree</td>
#       <td id="T_7e252_row1_col1" class="data row1 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_7e252_level0_row2" class="row_heading level0 row2" >1</th>
#       <td id="T_7e252_row2_col0" class="data row2 col0" >neutral</td>
#       <td id="T_7e252_row2_col1" class="data row2 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_7e252_level0_row3" class="row_heading level0 row3" >2</th>
#       <td id="T_7e252_row3_col0" class="data row3 col0" >agree</td>
#       <td id="T_7e252_row3_col1" class="data row3 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_7e252_level0_row4" class="row_heading level0 row4" >3</th>
#       <td id="T_7e252_row4_col0" class="data row4 col0" >strongly agree</td>
#       <td id="T_7e252_row4_col1" class="data row4 col1" >4</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_1c404 th {
#   background-color: #ff9933;
#   color: white;
# }
# #T_1c404 td {
#   border: 1px solid #ff9933;
#   padding: 5px;
# }
# #T_1c404_row0_col0 {
#   text-align: center;
#   font-size: 16px;
#   font-weight: bold;
#   font-family: Arial;
# }
# </style>
# <table id="T_1c404">
#   <caption>Median Higher Tax Value</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1c404_level0_col0" class="col_heading level0 col0" >Median Higher Tax</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1c404_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1c404_row0_col0" class="data row0 col0" >2.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# We assign a categorical order to the 'higher_tax' column using pd.Categorical() with the specified order and ordered=True. We print out the unique values in the 'higher_tax' column.
#
# Then, we label encode the 'higher_tax' column using census['higher_tax'].cat.codes and print out the median value of the encoded column.
#
# # **One-Hot Encoding**

# %%
# Apply one-hot encoding to the 'marital_status' column
census = pd.get_dummies(census, columns=['marital_status'])

# Apply styling to the DataFrame
styled_census = census.style.set_properties(**{'text-align': 'center', 'font-size': '12px', 'font-family': 'Arial'})\
                                      .set_caption('First 5 Rows of Census Data')\
                                      .set_table_styles([{'selector': 'th', 'props': [('background-color', '#66b3ff'), ('color', 'white')]},
                                                         {'selector': 'td', 'props': [('border', '1px solid #66b3ff'), ('padding', '5px')]}])\
                                      .background_gradient(cmap='YlGnBu')
#Display the styled DataFrame
display(styled_census)
# Out:
# <style type="text/css">
# #T_e2462 th {
#   background-color: #66b3ff;
#   color: white;
# }
# #T_e2462 td {
#   border: 1px solid #66b3ff;
#   padding: 5px;
# }
# #T_e2462_row0_col0, #T_e2462_row0_col1, #T_e2462_row0_col3, #T_e2462_row0_col7, #T_e2462_row0_col8, #T_e2462_row0_col9, #T_e2462_row0_col10, #T_e2462_row1_col0, #T_e2462_row1_col1, #T_e2462_row1_col3, #T_e2462_row1_col7, #T_e2462_row1_col8, #T_e2462_row1_col9, #T_e2462_row1_col10, #T_e2462_row2_col0, #T_e2462_row2_col1, #T_e2462_row2_col3, #T_e2462_row2_col7, #T_e2462_row2_col8, #T_e2462_row2_col9, #T_e2462_row2_col10, #T_e2462_row3_col0, #T_e2462_row3_col1, #T_e2462_row3_col3, #T_e2462_row3_col7, #T_e2462_row3_col8, #T_e2462_row3_col9, #T_e2462_row3_col10, #T_e2462_row4_col0, #T_e2462_row4_col1, #T_e2462_row4_col3, #T_e2462_row4_col7, #T_e2462_row4_col8, #T_e2462_row4_col9, #T_e2462_row4_col10, #T_e2462_row5_col0, #T_e2462_row5_col1, #T_e2462_row5_col3, #T_e2462_row5_col7, #T_e2462_row5_col8, #T_e2462_row5_col9, #T_e2462_row5_col10, #T_e2462_row6_col0, #T_e2462_row6_col1, #T_e2462_row6_col3, #T_e2462_row6_col7, #T_e2462_row6_col8, #T_e2462_row6_col9, #T_e2462_row6_col10, #T_e2462_row7_col0, #T_e2462_row7_col1, #T_e2462_row7_col3, #T_e2462_row7_col7, #T_e2462_row7_col8, #T_e2462_row7_col9, #T_e2462_row7_col10, #T_e2462_row8_col0, #T_e2462_row8_col1, #T_e2462_row8_col3, #T_e2462_row8_col7, #T_e2462_row8_col8, #T_e2462_row8_col9, #T_e2462_row8_col10, #T_e2462_row9_col0, #T_e2462_row9_col1, #T_e2462_row9_col3, #T_e2462_row9_col7, #T_e2462_row9_col8, #T_e2462_row9_col9, #T_e2462_row9_col10, #T_e2462_row10_col0, #T_e2462_row10_col1, #T_e2462_row10_col3, #T_e2462_row10_col7, #T_e2462_row10_col8, #T_e2462_row10_col9, #T_e2462_row10_col10, #T_e2462_row11_col0, #T_e2462_row11_col1, #T_e2462_row11_col3, #T_e2462_row11_col7, #T_e2462_row11_col8, #T_e2462_row11_col9, #T_e2462_row11_col10, #T_e2462_row12_col0, #T_e2462_row12_col1, #T_e2462_row12_col3, #T_e2462_row12_col7, #T_e2462_row12_col8, #T_e2462_row12_col9, #T_e2462_row12_col10, #T_e2462_row13_col0, #T_e2462_row13_col1, #T_e2462_row13_col3, #T_e2462_row13_col7, #T_e2462_row13_col8, #T_e2462_row13_col9, #T_e2462_row13_col10, #T_e2462_row14_col0, #T_e2462_row14_col1, #T_e2462_row14_col3, #T_e2462_row14_col7, #T_e2462_row14_col8, #T_e2462_row14_col9, #T_e2462_row14_col10, #T_e2462_row15_col0, #T_e2462_row15_col1, #T_e2462_row15_col3, #T_e2462_row15_col7, #T_e2462_row15_col8, #T_e2462_row15_col9, #T_e2462_row15_col10, #T_e2462_row16_col0, #T_e2462_row16_col1, #T_e2462_row16_col3, #T_e2462_row16_col7, #T_e2462_row16_col8, #T_e2462_row16_col9, #T_e2462_row16_col10, #T_e2462_row17_col0, #T_e2462_row17_col1, #T_e2462_row17_col3, #T_e2462_row17_col7, #T_e2462_row17_col8, #T_e2462_row17_col9, #T_e2462_row17_col10, #T_e2462_row18_col0, #T_e2462_row18_col1, #T_e2462_row18_col3, #T_e2462_row18_col7, #T_e2462_row18_col8, #T_e2462_row18_col9, #T_e2462_row18_col10, #T_e2462_row19_col0, #T_e2462_row19_col1, #T_e2462_row19_col3, #T_e2462_row19_col7, #T_e2462_row19_col8, #T_e2462_row19_col9, #T_e2462_row19_col10, #T_e2462_row20_col0, #T_e2462_row20_col1, #T_e2462_row20_col3, #T_e2462_row20_col7, #T_e2462_row20_col8, #T_e2462_row20_col9, #T_e2462_row20_col10, #T_e2462_row21_col0, #T_e2462_row21_col1, #T_e2462_row21_col3, #T_e2462_row21_col7, #T_e2462_row21_col8, #T_e2462_row21_col9, #T_e2462_row21_col10, #T_e2462_row22_col0, #T_e2462_row22_col1, #T_e2462_row22_col3, #T_e2462_row22_col7, #T_e2462_row22_col8, #T_e2462_row22_col9, #T_e2462_row22_col10, #T_e2462_row23_col0, #T_e2462_row23_col1, #T_e2462_row23_col3, #T_e2462_row23_col7, #T_e2462_row23_col8, #T_e2462_row23_col9, #T_e2462_row23_col10, #T_e2462_row24_col0, #T_e2462_row24_col1, #T_e2462_row24_col3, #T_e2462_row24_col7, #T_e2462_row24_col8, #T_e2462_row24_col9, #T_e2462_row24_col10, #T_e2462_row25_col0, #T_e2462_row25_col1, #T_e2462_row25_col3, #T_e2462_row25_col7, #T_e2462_row25_col8, #T_e2462_row25_col9, #T_e2462_row25_col10, #T_e2462_row26_col0, #T_e2462_row26_col1, #T_e2462_row26_col3, #T_e2462_row26_col7, #T_e2462_row26_col8, #T_e2462_row26_col9, #T_e2462_row26_col10, #T_e2462_row27_col0, #T_e2462_row27_col1, #T_e2462_row27_col3, #T_e2462_ro ...

# %% [markdown]
# We apply one-hot encoding (OHE) to the 'marital_status' column using pd.get_dummies(), creating new binary columns for each unique value in the 'marital_status' column.
#
# Finally, we print out the first 5 rows of the updated census dataframe to inspect the changes made after applying one-hot encoding.
